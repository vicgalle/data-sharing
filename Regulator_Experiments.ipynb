# %%
from reinforce import *

# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ## $swf$ for 5 simulations, utilitarian

# %%
N_exps = 5
N = 1000

SUs = []


for i in range(N_exps):
    SUs.append([run_data_coop_game(i,N=N), 
                run_data_coop_game_with_regulator(i, N=N),
                run_data_coop_game_with_gaussian_regulator(i+55,N=N)])
    
SUs = np.array(SUs)

colors = onp.asarray(['red', 'magenta', 'blue'])

smooth = 50
for i in range(3):
    for j in range(N_exps):
        plt.plot(np.convolve(SUs[j, i, :, 0], np.ones(smooth)/smooth, mode='valid'), color=colors[i], alpha=0.1)
    plt.plot(np.convolve(SUs.mean(axis=0)[i, :, 0], np.ones(smooth)/smooth, mode='valid'), color=colors[i])
# Out:
# [[ 1.3162217 -1.332907 ]] [[ 1.274965 -1.276974]]
# logits: [[ 0.81794155 -0.617942  ]] [[ 1.1051407 -0.9051416]] [[0.09716728 0.0673849  0.09075523 0.1446926 ]] [[0.09716728 0.0673849  0.09075523 0.1446926 ]]
# mean SU: 2.146
# mean tax1 0.24900001
# mean tax2 0.24900001
# logits: [[-0.3378801  2.3378818]] [[1.4696913 0.5303105]] [-1.1370857] [2.955432]
# mean SU: 3.316
# mean tax1 0.20330937
# mean tax2 0.4079173
# [[ 1.3939188 -1.4463911]] [[ 1.4025955 -1.373622 ]]
# logits: [[ 1.0550184  -0.85501856]] [[ 0.7168    -0.5168005]] [[0.11687115 0.1005749  0.08074003 0.10181393]] [[0.11687115 0.1005749  0.08074003 0.10181393]]
# mean SU: 2.22
# mean tax1 0.24155001
# mean tax2 0.24155001
# logits: [[1.3245788  0.67542124]] [[0.47902587 1.5209732 ]] [0.36477393] [-1.3350413]
# mean SU: 2.826
# mean tax1 0.31300685
# mean tax2 0.2695441
# [[ 1.258116  -1.2827258]] [[ 1.3112856 -1.3503045]]
# logits: [[-0.11707287  0.31707296]] [[ 0.90979695 -0.70979744]] [[0.07789804 0.12770978 0.11342864 0.08096358]] [[0.07789804 0.12770978 0.11342864 0.08096358]]
# mean SU: 2.882
# mean tax1 0.24260001
# mean tax2 0.24260001
# logits: [[0.513584  1.4864163]] [[1.3257216  0.67427796]] [1.2989441] [6.160208]
# mean SU: 2.922
# mean tax1 0.31381097
# mean tax2 0.45427406
# [[ 1.254472  -1.2863951]] [[ 1.2781676 -1.3752836]]
# logits: [[ 0.9357794 -0.7357793]] [[ 0.7721217  -0.57212144]] [[0.11322611 0.11396904 0.0743937  0.09841115]] [[0.11322611 0.11396904 0.0743937  0.09841115]]
# mean SU: 2.38
# mean tax1 0.23244998
# mean tax2 0.23244998
# logits: [[0.96290386 1.0370932 ]] [[1.9131495  0.08685177]] [-4.2653646] [0.68945515]
# mean SU: 2.572
# mean tax1 0.08530118
# mean tax2 0.30356458
# [[ 1.1306249 -1.0733712]] [[ 1.0939566 -1.1709611]]
# logits: [[ 0.6503721 -0.4503715]] [[ 0.2231701  -0.02316989]] [[0.13199733 0.06930898 0.0975229  0.10117085]] [[0.13199733 0.06930898 0.0975229  0.10117085]]
# mean SU: 3.034
# mean tax1 0.24014999
# mean tax2 0.24014999
# logits: [[0.4482236 1.5517751]] [[1.7363955  0.26360238]] [-1.2839268] [1.7118146]
# mean SU: 3.224
# mean tax1 0.23009342
# mean tax2 0.42457348

# %%
colors = onp.asarray(['red', 'magenta', 'blue'])

smooth = 50
for i in range(3):
    for j in range(N_exps):
        plt.plot(np.convolve(SUs[j, i, :, 0], np.ones(smooth)/smooth, mode='valid'), color=colors[i], alpha=0.1)
    plt.plot(np.convolve(SUs.mean(axis=0)[i, :, 0], np.ones(smooth)/smooth, mode='valid'), color=colors[i])
    plt.xlabel('time, $t$')
    plt.ylabel('Social utility, $SU_t$')
    
from matplotlib.lines import Line2D
cmap = plt.cm.coolwarm
custom_lines = [Line2D([0], [0], color='red'),
                Line2D([0], [0], color='magenta'),
                Line2D([0], [0], color='blue')]

plt.legend(custom_lines,['No intervention', 'Regulator (Disc.)', 'Regulator (Gauss.)'], loc=2);
